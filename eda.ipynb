# %%
import duckdb
import pandas as pd

con = duckdb.connect('data/rituals.duckdb', read_only=True)

# Test
df = con.execute("SELECT COUNT(*) FROM marts.fact_pull_requests").df()
print(df)
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[6], line 4
#       1 import duckdb
#       2 import pandas as pd
# ----> 4 con = duckdb.connect('data/rituals.duckdb', read_only=True)
#       6 # Test
#       7 df = con.execute("SELECT COUNT(*) FROM marts.fact_pull_requests").df()
#
# IOException: IO Error: Could not set lock on file "/Users/davidorozco/Documents/rituals/data/rituals.duckdb": Conflicting lock is held in /Applications/DBeaver.app/Contents/MacOS/dbeaver (PID 2167) by user davidorozco. See also https://duckdb.org/docs/connect/concurrency
